# %%
from tweepy import Stream
import pandas as pd
import numpy as np
import tweepy
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import argparse
import string
from twython import Twython  
import json
from sklearn import preprocessing
import gensim 
import re, string
import nltk
import contractions
import inflect
from bs4 import BeautifulSoup
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from nltk import re
import os
import sys

# %% [markdown]
# Using the following function, we get the latest tweets in the last time frame.

# %%
def get_latest_tweets(data_dir, auth, time_limit, topic):

    print("streaming tweets...")
    tic = time.time()
    twitter_stream = Stream(auth, MyListener(data_dir, time_limit), tweet_mode='extended')
    twitter_stream.filter(track = topic) # list of querries to track
    t = time.time()
    print('stream data are saved in '+ str((t-tic)/60)+' minutes')
    print('reading stream file...')
    data = pd.read_json(data_dir+"stream.json", lines=True)
    ll = time.time()
    print('reading the stream file takes ' + str((ll-t)/60) +' minutes')
    tweets = pd.DataFrame(columns=['time', 'tweet'], index=data.index)
    print('getting full_text tweets...')
    no_data = False
    if data.empty:
        no_data = True
    else:
        data = data[data.lang == 'en']
        tweets=pd.DataFrame(columns = ['time','tweet'], index=data.index)
        tweets['tweet'] = data.apply(lambda x: get_full_text_tweet(x), axis = 1)
        tweets['time'] = data.created_at
        tweets = tweets.sort_values('time', ascending=False)
        tweets = tweets.drop_duplicates()
        tweets = tweets.dropna(subset = ['tweet'])
    toc = time.time()
    print(str(tweets.shape[0])+ ' full_text tweets obtained in ' + str((toc-tic)/60) + ' minutes', tweets)
    return tweets, no_data

# %% [markdown]
# The following function, get the full text of the tweet.

# %%
def get_full_text_tweet(tweet):
   if pd.isnull(tweet.retweeted_status):
         if pd.isnull(tweet.extended_tweet):
                full_text = tweet.text
         else:   
            if "full_text" in tweet.extended_tweet.keys():
                 full_text = tweet.extended_tweet["full_text"]

            else:
                 full_text = tweet.text 
   else:
        if 'extended_tweet' in tweet.retweeted_status.keys():
            if "full_text" in tweet.retweeted_status['extended_tweet'].keys():
                full_text = tweet.retweeted_status['extended_tweet']["full_text"]
        else:
             full_text = tweet.retweeted_status['text']    
   return full_text

# %%
#MyListener() saves the data into a .json file with name stream
class MyListener(StreamListener):
    """Custom StreamListener for streaming data."""

    def __init__(self, data_dir, time_limit):
        self.start_time = time.time()
        self.limit = time_limit
        self.saveFile = open(data_dir + "stream.json", 'a')
        super(MyListener, self).__init__()

    def on_data(self, data):
        if (time.time() - self.start_time) < self.limit:
            self.saveFile.write(data)
            return True
        else:
            self.saveFile.close()
            return False
            

    def on_error(self, status):
        print(status)
        return True

# %% [markdown]
# The following functions, helps to clean the tweets for modeling.

# %%
def tokenize_tweet(tweet):
    tokens = [str(word) for word in str(tweet).lower().split()];
    return(tokens);

def remove_punctuation(tokens):
    clean_words = [word.translate(str.maketrans('', '', string.punctuation)) for word in tokens];
    return(clean_words);

def clean_text(model, clean_words):
    stoplist = set(stopwords.words('english'));
    tweet_nostopwords = [word for word in clean_words if word not in stoplist];
    filtered_word_list = [word for word in tweet_nostopwords if word in model.vocab];
    return(filtered_word_list);

# %%
def tweet_preprocess(row_tweet,model):
    return clean_text(model,remove_punctuation(tokenize_tweet(row_tweet)))

# %% [markdown]
# Using the following function, we use a model as an input , to vectorize  normalized tweets.

# %%
def vectorize_tweet(normalized_tweet,model):
    vec=np.zeros((300))
    for word in normalized_tweet:
        vec += model[word] 
    return preprocessing.normalize(vec.reshape(1,-1))

# %%
def vectorize_latest_tweets(tweets, model):
    
    print('vectorizing tweets...')
    tic = time.time()
    tweets.loc[:,'normalized'] = tweets.tweet.apply(lambda tweet: tweet_preprocess(tweet, model))
    tweets.loc[:,'vector'] = tweets.normalized.apply(lambda tweet: vectorize_tweet(tweet, model))
    toc=time.time()
    print('tweets vectorizd in '+ str((toc-tic)/60)+' minutes')
    return tweets

# %%
def vectorize_user_input(user_input, model):
    
    print('vectorizing user_input...')
    normalized = tweet_preprocess(user_input, model)
    word_vec = vectorize_tweet(normalized, model)
    vectorized_input = {'raw_input': user_input, 'normalized': normalized, 'vector': word_vec}      
    print('user_input is vectorized!')
    return vectorized_input

# %%
def find_most_similar_tweets(vectorized_input, vectorized_tweets, topn):
    vec_tweets = np.vstack(vectorized_tweets.vector.apply(lambda x: x.tolist()))
    cos=model.cosine_similarities(vectorized_input['vector'].reshape(-1,), vec_tweets)
    vectorized_tweets.loc[:,'similarity_score'] = cos 
    vectorized_tweets = vectorized_tweets.sort_values(by='similarity_score', ascending=False)
    return vectorized_tweets[0:topn]

# %%
def process_user_input(user_input, time_limit, topic, topn):

    track_list = [k for k in topic.split(',')]
    file_name = "stream"
    if os.path.exists(data_dir+file_name + '.json'):
        os.remove(data_dir + file_name + '.json')
    #-----------------------------------------------
    # Load credentials from json file
    tweets, no_data = get_latest_tweets(data_dir, auth, time_limit, track_list)
    if no_data:
        return 'There is no data with topic: '+ topic +' in  '+ str(time_limit) +' seconds'
    else:
        vectorized_tweets = vectorize_latest_tweets(tweets, model)
        vectorized_user_input = vectorize_user_input(user_input, model)
        #find the top topn= 10  similar tweets
        recommendations = find_most_similar_tweets(vectorized_user_input, vectorized_tweets, topn)
        print('top '+ str(topn) + ' similar tweets are obtained!')
    return recommendations

# %%
#downloaded pretrained model
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary = True)

# %%
data_dir = './stream/data/'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(data_dir) if isfile(join(data_dir, f))]
onlyfiles
# Out:
# [' stream_topic.json',
#  '.DS_Store',
#  'data.json',
#  'fetched_tweets.txt',
#  'file_name',
#  'stream.json',
#  'stream__Asian_food.json',
#  'stream_Asian_food.json',
#  'stream_food.json',
#  'stream_politics.json',
#  't.json']

# %%
data_dir = './'
topic = 'Canada' #it can be a list of topics,  comman means 'or'
topn = 10
time_limit = 20
user_input = 'Tarif'
with open(data_dir + "twitter_credentials.json", "r") as file:  
     credentials = json.load(file)
# Instantiate an object
python_tweets = Twython( credentials['CONSUMER_KEY'], credentials['CONSUMER_SECRET'])
auth = tweepy.OAuthHandler(credentials['CONSUMER_KEY'], credentials['CONSUMER_SECRET'])
auth.set_access_token(credentials['ACCESS_TOKEN'], credentials['ACCESS_SECRET'])

# %%
recommendations = process_user_input(user_input, time_limit, topic, topn)

# %%
recommendations.iloc[0]['tweet']
# Out:
# 'Global marijuana trade is still five to seven years off\n\nUnder the Cannabis Act, Canadian producers are currently only allowed to export weed for medical use, and then only to countries that allow cannabis to be imported.\n\nhttps://t.co/n036yiuaPy'

# %%
recommendations
# Out:
#                   time                                              tweet  \
# 20 2019-06-19 14:32:23  Global marijuana trade is still five to seven ...
# 26 2019-06-19 14:32:25  American Insulin Scandal: Vial of Humalog from...
# 35 2019-06-19 14:32:29  Privatization &amp; ever more privatization. T...
# 19 2019-06-19 14:32:23  FINALLY! Canada has banned shark fin imports a...
# 41 2019-06-19 14:32:32  AMAZING! Canada passed legislation to put an e...
# 23 2019-06-19 14:32:25  141,900 square feet of artificial turf importe...
# 47 2019-06-19 14:32:33  In our last #FBCountryIndex Canada ranked 8th ...
# 11 2019-06-19 14:32:20  Tiny House Warriors respond to Canada’s announ...
# 40 2019-06-19 14:32:31  Webinar this week: Join Food Allergy Canada's ...
# 17 2019-06-19 14:32:22  I’m going to try my hand at translating. \n\nT...
#
#                                            normalized  \
# 20  [global, marijuana, trade, still, five, seven,...
# 26  [american, insulin, scandal, vial, eli, lilly,...
# 35  [privatization, amp, ever, privatization, buy,...
# 19  [finally, canada, banned, shark, fin, imports,...
# 41  [amazing, canada, passed, legislation, put, en...
# 23  [square, feet, artificial, turf, imported, fra...
# 47  [last, canada, ranked, 8th, environmental, fri...
# 11  [tiny, house, warriors, respond, announcement,...
# 40  [webinar, week, join, food, allergy, webinar, ...
# 17  [going, try, hand, translating, puppet, puppet...
#
#                                                vector  similarity_score
# 20  [[0.029329505649927836, 0.013802065266448206, ...          0.278243
# 26  [[-0.04532776933211481, 0.06511309352842061, 0...          0.274862
# 35  [[-0.05269165186022342, 0.003248564575928917, ...          0.269835
# 19  [[-0.009868834595657796, 0.04313267093561433, ...          0.254936
# 41  [[-0.03511252114909569, 0.018028544242165667, ...          0.227339
# 23  [[-0.08134927342802921, 0.0635687164262338, 0....          0.216241
# 47  [[-0.03796684711200454, 0.11958902120645264, -...          0.205407
# 11  [[0.051278696066418, 0.047228611905171664, 0.0...          0.190744
# 40  [[-0.05409327902854551, -0.01027698925766548, ...          0.184940
# 17  [[0.07208209450574447, -0.02368210062479829, 0...          0.179053

# %%
with pd.option_context('display.max_colwidth', 300):
    print (recommendations)
# Out:
#                   time  \
# 5  2019-06-01 14:19:49
# 15 2019-06-01 14:19:51
# 12 2019-06-01 14:19:51
# 11 2019-06-01 14:19:51
# 40 2019-06-01 14:20:00
# 37 2019-06-01 14:19:58
# 20 2019-06-01 14:19:53
# 46 2019-06-01 14:20:01
# 10 2019-06-01 14:19:50
# 53 2019-06-01 14:20:03
# 7  2019-06-01 14:19:49
# 33 2019-06-01 14:19:57
# 34                                                                                                                                                                        [meanwhile, trump, branded, canada, national, security, threat]
# 30                                                                                                                              [btw, canada, politicians, expense, accounts, listed, online, see, many, absolutely, blow, mind, example]
# 14                                       [im, calling, resisters, help, spread, word, us, canada, want, andrew, trump, lite, prime, minister, elected, canada, us, controlled, racist, pro, hate, anti, choice, leaders, resisters, help]
# 49                                                                                                                                        [9, illegal, pot, dispensaries, vancouver, must, close, court, decision, city, says, cbc, news]
# 0                                                                                                                                                                             [btw, offer, regions, youre, canada, dont, need, worry, dm]
# 28                                                                                      [ya, beauty, jake, think, big, dman, brandon, wheat, kings, took, year, mind, seeing, shen, come, seen, canada, russia, series, year, kid, skill]
# 2                                                                                                                                                                       [approves, plan, develop, first, tiny, homes, community, country]
# 23                                                                  [chef, nouveau, parti, singh, addresses, municipal, leaders, innovative, creative, less, service, residents, want, canada, people, live, thrive, future, generations]
# 54                                                                                                                                                                      [frederick, registered, want, join, signup, canada, ultrarunning]
# 18                                                                                                [wheres, chart, itunes, album, chart, uk, canada, charts, itunes, charts, please, nik, pick, posting, whats, gonna, look, great, faves]
# 55                                                                                       [river, log, episode, corey, finds, pinch, josh, collins, heads, canada, send, unleashed, whitewater, competition, whitewater, stakeout, canada]
# 51                                                                                                                                  [welcome, ndp, leader, singh, sharing, vision, canada, pleased, four, federally, leaders, conference]
# 16                                                                                                                    [mean, ensure, everyone, party, thinks, certain, way, duh, thankful, freedom, thought, belief, conservative, party]
# 9                                                                                                                                                            [nobrainer, dr, remarkably, intelligent, poised, would, represent, us, well]
# 29                                                                                                                                                                                                                        [shock, canada]
# 31                                                                                                                                                                       [make, mistake, andrew, pulling, strings, racist, canada, proud]
# 43                                                                                                                                                                                                 [entitled, opinion, would, good, live]
# 39                                                                         [beautiful, wife, mary, seen, bit, fans, general, public, massive, attack, western, canada, issues, spells, strong, cannot, pick, danger, going, us, critical]
# 8                                                                                                                 [sounds, familiar, line, items, could, total, millions, lot, steak, used, mask, secret, scandals, made, headlines, lot]
# 36                                                                                                                                                                   [ready, get, back, canada, next, week, one, best, tournaments, year]
# 3                                                                                                                                                                                                        [bro, feel, try, living, canada]
# 24                                                                                                                                                                                                                        [south, africa]
# 52                                                                                                              [know, full, well, canada, legalizing, perfectly, harmless, substance, votes, wanting, control, got, control, backfiring]
# 44                                                                                                                                                                                                                                [bimbo]
# 47                                                                                                                                                           [wishing, baby, orca, good, luck, survival, precarious, time, ocean, health]
# 19                                                                                                                                                                                     [still, understand, news, canada, leading, hockey]
# 17                                                                                                                                                                                       [newborn, baby, orca, spotted, swimming, j, pod]
# 42                                                                                                                                                                                                                                [thank]
#
#                                                                                                                                                                                                                                                                                                          vector  \
# 5   [[-0.029142514252135713, -0.039270194317686476, -0.00023218838776335605, 0.14007113184632933, -0.030335453883965816, -0.01275149089264339, 0.025466881823938414, -0.10514934196378696, 0.10437811551679914, 0.08959354043730912, -0.08910783186644018, -0.08881903217565326, -0.034820053627833324, -0.0...
